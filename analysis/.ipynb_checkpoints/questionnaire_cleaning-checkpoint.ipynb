# %%
import pandas as pd
from pathlib import Path

# %%
table_path = Path.cwd()
table_name = table_path / "questionnaire_results.xlsx"

table_name
# Out:
# WindowsPath('D:/thesis-matlab-pipeline/analysis/questionnaire_results.xlsx')

# %%
df = pd.read_excel(table_name)

df
# Out:
#    Participant poc_cue poc_face hp_cue hp_face im_cue im_face am_cue am_face
# 0           JW       5        5      5       5      5       5      5       5
# 1           SG      3!       5!     5!      4!     3!      3!     5!      5!
# 2           AS      3!       5!     5!      4!     3!      3!     5!      5!
# 3           NH       3        5      5       5      0       5      5       5
# 4           ET       4        5      5       4      4       4      5       5
# 5           LK       3        5      5       5      4       3      5       5
# 6           JF       0        5      2       2      2       5      5       5
# 7           RR       4        4      5       5      4       4      5       5
# 8           MH       3        4      5       2      3       0      4       5
# 9           YM       5        5      5       5      0       3      5       5
# 10          KL       4        5      5       4      3       4      5       5
# ...
